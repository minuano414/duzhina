# %%
import pandas as pd
df = pd.read_table("F:\МФТИ\Хакатон\metadata.txt", index_col=False, sep="}{")
df
# Out:
# C:\Users\ttnch\AppData\Local\Temp\ipykernel_20176\3022610539.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_table("F:\МФТИ\Хакатон\metadata.txt", index_col=False, sep="}{")
#                                                         {
# 0                                            "streams": [
# 1                                                       {
# 2                                             "index": 0,
# 3                                   "codec_name": "h264",
# 4       "codec_long_name": "H.264 / AVC / MPEG-4 AVC /...
# ...                                                   ...
# 323114           "compatible_brands": "isomiso2avc1mp41",
# 323115                         "encoder": "Lavf58.20.100"
# 323116                                                  }
# ...

# %%
pd.set_option('display.max_rows', 150)

# %%
df.head(150)
# Out:
#                                                      {
# 0                                         "streams": [
# 1                                                    {
# 2                                          "index": 0,
# 3                                "codec_name": "h264",
# 4    "codec_long_name": "H.264 / AVC / MPEG-4 AVC /...
# 5                                   "profile": "High",
# 6                               "codec_type": "video",
# 7                          "codec_tag_string": "avc1",
# 8                           "codec_tag": "0x31637661",
# 9                                        "width": 554,
# 10                                      "height": 404,
# 11                                 "coded_width": 554,
# 12                                "coded_height": 404,
# 13                               "closed_captions": 0,
# 14                                  "has_b_frames": 2,
# 15                       "sample_aspect_ratio": "1:1",
# ...

# %%
df.transpose()
# Out:
#          0      1            2                      3       \
# {  "streams": [      {  "index": 0,  "codec_name": "h264",
#
#                                               4                   5       \
# {  "codec_long_name": "H.264 / AVC / MPEG-4 AVC /...  "profile": "High",
#
#                    6                            7       \
# {  "codec_type": "video",  "codec_tag_string": "avc1",
#
#                        8              9       ...                 323109  \
# {  "codec_tag": "0x31637661",  "width": 554,  ...  "bit_rate": "866341",
#
#                 323110     323111                  323112  \
# {  "probe_score": 100,  "tags": {  "major_brand": "isom",
#
#                     323113                                    323114  \
# {  "minor_version": "512",  "compatible_brands": "isomiso2avc1mp41",
#
#                        323115 323116 323117 323118
# {  "encoder": "Lavf58.20.100"      }      }      }
#
# [1 rows x 323119 columns]
