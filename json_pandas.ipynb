# %%
import pandas as pd
df = pd.read_table("F:\МФТИ\Хакатон\metadata_1.txt", index_col=False, sep="}{")
df
# Out:
# C:\Users\ttnch\AppData\Local\Temp\ipykernel_20176\3850563385.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_table("F:\МФТИ\Хакатон\metadata_1.txt", index_col=False, sep="}{")
#                                                {
# 0                                   "streams": [
# 1                                              {
# 2                                    "index": 0,
# 3                          "codec_name": "text",
# 4           "codec_long_name": "raw UTF-8 text",
# ...                                          ...
# 428083  "compatible_brands": "isomiso2avc1mp41",
# 428084                "encoder": "Lavf58.20.100"
# 428085                                         }
# 428086                                         }
# ...

# %%
pd.set_option('display.max_rows', 150)

# %%
df.head(150)
# Out:
#                                                      {
# 0                                         "streams": [
# 1                                                    {
# 2                                          "index": 0,
# 3                                "codec_name": "text",
# 4                 "codec_long_name": "raw UTF-8 text",
# 5                            "codec_type": "subtitle",
# 6                  "codec_tag_string": "[0][0][0][0]",
# 7                               "codec_tag": "0x0000",
# 8                               "r_frame_rate": "0/0",
# 9                             "avg_frame_rate": "0/0",
# 10                              "time_base": "1/1000",
# 11                                    "disposition": {
# 12                                       "default": 0,
# 13                                           "dub": 0,
# 14                                      "original": 0,
# 15                                       "comment": 0,
# ...

# %%
df.transpose()
# Out:
#          0      1            2                      3       \
# {  "streams": [      {  "index": 0,  "codec_name": "text",
#
#                                  4                          5       \
# {  "codec_long_name": "raw UTF-8 text",  "codec_type": "subtitle",
#
#                                 6                       7       \
# {  "codec_tag_string": "[0][0][0][0]",  "codec_tag": "0x0000",
#
#                    8                         9       ...  \
# {  "r_frame_rate": "0/0",  "avg_frame_rate": "0/0",  ...
#
#                    428078               428079     428080  \
# {  "bit_rate": "1345709",  "probe_score": 100,  "tags": {
#
#                    428081                   428082  \
# {  "major_brand": "isom",  "minor_version": "512",
#
#                                      428083                      428084  \
# {  "compatible_brands": "isomiso2avc1mp41",  "encoder": "Lavf58.20.100"
#
#   428085 428086 428087
# {      }      }      }
#
# [1 rows x 428088 columns]
